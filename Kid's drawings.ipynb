# %% [markdown]
# # Kid's drawings

# %% [markdown]
# In this project we get a number of pictures of drawings drawn by children, and have to do a number of tasks.

# %% [markdown]
# ### Let's look at the data we have:

# %% [markdown]
# For each painting we have a picture of him and a table with several columns:
# * X-Y: Represent a dot on the drawing.
# * Pressure: Press the pen on the page at any point.
# * TiltX, TiltY: Pen position on the dot.
# * Time: The time you drew the drawing.

# %% [markdown]
# We will import the libraries we will need to use:

# %%
import numpy as np
import os
from PIL import Image
from tabulate import tabulate
import pandas as pd

# %% [markdown]
# We open an example of a drawing in his table:

# %%
df_draw=pd.read_csv('C:/Users/user/Desktop/תואר ראשון מדמח/שנה א/סמסטר ב/הדמיית נתונים/data/train/7572/SimpleTest/1.csv')
df_draw
# Out:
#                                                    X           Y   Pressure  \
# 0                                           585.5325  482.853333   0.264160
# 1                                             585.39  482.600000   0.280518
# 2                                           586.1025  481.840000   0.324219
# 3                                           589.5225  480.573333   0.402344
# 4                                           590.6625  480.193333   0.417969
# 5                                           595.5075  479.053333   0.464844
# 6                                             597.36  478.800000   0.480469
# 7                                           602.9175  477.660000   0.527344
# 8                                           609.1875  476.266667   0.574219
# 9                                           611.4675  475.760000   0.589844
# 10                                          621.1575  474.366667   0.652344
# ...

# %%
img = Image.open('C:/Users/user/Desktop/תואר ראשון מדמח/שנה א/סמסטר ב/הדמיית נתונים/data/train/7572/SimpleTest/1.png')
img.show()

# %% [markdown]
# ### 1. We will count how many lines there are in each picture:
